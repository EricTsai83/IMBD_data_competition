# %% [markdown]
# # Model training: [CatBoost](https://github.com/catboost/catboost)
# ---
# Description:
#
# In this notebook, you can generate two solutions.
# One is using 6 `single output regressor` to predict 6 target variable respectively, and the other is `muti-output regressor` that can output 6 predictions of target variable. It depends on `model_train_config.py` to lead the data flow.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
# basic
import pandas as pd
import numpy as np
import pickle
import model_train_config
# utils
from utils.time_utils import current_time
from utils.metric_utils import rmse_score
# model
from catboost import CatBoostRegressor
from catboost import cv, Pool
# config
import feature_engineering_config as fe_config
# feature engineering
from feature_engineering import Standardization

# %% [markdown]
# ## 2. Config

# %%
random_state = model_train_config.random_state

# %% [markdown]
# ## 3. Load Data

# %%
with open(f'../Data/meta/train_x_after_feature_engineering.pickle', 'rb') as f:
    train_x_after_fe = pickle.load(f)

# %%
with open(f'../Data/meta/train_y_after_feature_engineering.pickle', 'rb') as f:
    train_y_after_fe = pickle.load(f)

# %%
# You need to use original values of target variable to evaluate RMSE
with open(f'../Data/meta/non_scaled_train_y_after_feature_engineering.pickle', 'rb') as f:
    non_scaled_train_y = pickle.load(f)

# %%
train_y_after_fe.head()
# Out:
#    sensor_point5_i_value  sensor_point6_i_value  sensor_point7_i_value  \
# 0              -2.818367              -1.363911              -1.094471
# 1              -3.198302              -1.213496              -2.029310
# 2              -3.350275              -0.987873              -1.873504
# 3              -3.198302              -1.288703              -2.029310
# 4              -1.678564              -0.536627              -1.873504
#
#    sensor_point8_i_value  sensor_point9_i_value  sensor_point10_i_value
# 0              -1.636244              -0.747381               -2.730355
# 1              -1.678600              -1.199743               -2.905334
# 2              -1.720955              -0.093969               -2.730355
# 3              -1.593889              -1.802893               -3.080313
# 4              -1.212690              -1.199743               -1.563825

# %%
train_x_after_fe.head()
# Out:
#    clean_pressure11  clean_pressure23  clean_pressure31  clean_pressure33  \
# 0          0.997022         -2.388433         -0.843851         -2.240894
# 1          0.995513         -2.388208         -0.844471         -2.240395
# 2          0.995513         -2.388208         -0.844471         -2.240395
# 3          0.995513         -2.388208         -0.844471         -2.240395
# 4          1.006083         -2.390687         -0.854257         -2.261857
#
#    clean_pressure41  clean_pressure51  clean_pressure52  clean_pressure61  \
# 0          2.296172          2.122483         -2.895754          1.899981
# 1          2.296172          2.131458         -2.895754          1.899981
# 2          2.296172          2.131458         -2.895754          1.899981
# 3          2.296172          2.131458         -2.895754          1.899981
# 4          2.296172          2.126968         -2.894711          1.899981
#
#    clean_pressure62  clean_pressure71  ...  painting_g2_act_hvc_group  \
# 0         -0.765094          0.433714  ...                          1
# 1         -0.765295          0.425788  ...                          1
# 2         -0.765295          0.425788  ...                          1
# 3         -0.765295          0.425788  ...                          1
# 4         -0.774144          0.378860  ...                          1
#
#    painting_g4_act_a_air_group  painting_g4_act_hvv_group  \
# 0                            3                          3
# 1                            3                          3
# 2                            3                          3
# 3                            3                          3
# 4                            3                          3
#
#    painting_g8_act_f_air_group  painting_g8_act_t_air_group  \
# 0                            1                            0
# 1                            1                            2
# 2                            1                            2
# 3                            1                            2
# 4                            1                            2
#
#    painting_g10_act_t_air_group  painting_g11_act_hvc_group  \
# 0                             4                           1
# 1                             4                           1
# 2                             4                           1
# 3                             4                           1
# 4                             4                           1
#
#    env_rpi05_pm1_group  env_rpi07_pm1_group  env_rpi15_pm1_group
# 0                    4                    2                    2
# 1                    4                    2                    2
# 2                    4                    2                    2
# 3                    4                    2                    2
# 4                    4                    4                    2
#
# [5 rows x 97 columns]

# %%
categorical_features_indices = np.where(train_x_after_fe.dtypes != float)[0]

# %% [markdown]
# ## 4. Single Output Regressor
#
# Training model for each target variable.

# %%
single_output_model_dic = {}
for col_y in train_y_after_fe.columns:

    params = {
        'loss_function': 'RMSE',
        'random_seed': random_state,
        'early_stopping_rounds':100,
        'task_type': 'CPU',
        'verbose':False,
        'has_time':True,
    }
    model = CatBoostRegressor(**params)

    grid = {
        'learning_rate': [0.05, 0.07, 0.09, 0.3],
        'iterations': [50, 60, 70, 80, 90, 100, 120, ],
        'depth': [3, 4, 5, 6, 7],
        'l2_leaf_reg': [1, 3, 5, 7, 9],
        'grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide']
    }
    randomized_search_result = model.randomized_search(
        grid,
        X=train_x_after_fe,
        y=train_y_after_fe[col_y],
        cv=3,
        plot=False,
        verbose=False
    )
    
    single_output_model_dic[col_y] = {'model': model, 'randomized_search_result': randomized_search_result}
# Out:
# bestTest = 0.7168204577
# bestIteration = 97
#
#
# bestTest = 0.6982473377
# bestIteration = 93
#
#
# bestTest = 0.711567168
# bestIteration = 37
#
#
# bestTest = 0.725529971
# bestIteration = 98
#
#
# bestTest = 0.7035183267
# bestIteration = 34
#
#
# bestTest = 0.7077820346
# bestIteration = 68
#
#
# bestTest = 0.7161348069
# bestIteration = 89
#
#
# bestTest = 0.7138894293
# bestIteration = 31
#
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.7231186067
# bestIteration = 6
#
#
# bestTest = 0.6990322579
# bestIteration = 68
#
# Training on fold [0/3]
#
# bestTest = 0.6016065544
# bestIteration = 99
#
# Training on fold [1/3]
#
# bestTest = 0.6928381088
# bestIteration = 97
#
# Training on fold [2/3]
#
# bestTest = 0.6898138804
# bestIteration = 85
#
#
# bestTest = 0.4692543269
# bestIteration = 98
#
#
# bestTest = 0.4673527841
# bestIteration = 98
#
#
# bestTest = 0.4542795728
# bestIteration = 43
#
#
# bestTest = 0.4676451741
# bestIteration = 99
#
#
# bestTest = 0.4580370056
# bestIteration = 78
#
#
# bestTest = 0.4726047788
# bestIteration = 79
#
#
# bestTest = 0.472901102
# bestIteration = 89
#
#
# bestTest = 0.4535747554
# bestIteration = 95
#
#
# bestTest = 0.4451915331
# bestIteration = 20
#
#
# bestTest = 0.4652518557
# bestIteration = 69
#
# Training on fold [0/3]
#
# bestTest = 0.4832271978
# bestIteration = 12
#
# Training on fold [1/3]
#
# bestTest = 0.5678717129
# bestIteration = 9
#
# Training on fold [2/3]
#
# bestTest = 0.4535132166
# bestIteration = 16
#
#
# bestTest = 0.6186459322
# bestIteration = 99
#
#
# bestTest = 0.6123209566
# bestIteration = 78
#
#
# bestTest = 0.6387276284
# bestIteration = 17
#
#
# bestTest = 0.634640389
# bestIteration = 90
#
#
# bestTest = 0.6061168022
# bestIteration = 48
#
#
# bestTest = 0.6058202757
# bestIteration = 65
#
#
# bestTest = 0.63406005
# bestIteration = 79
#
#
# bestTest = 0.6227263619
# bestIteration = 48
#
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.615187225
# bestIteration = 6
#
#
# bestTest = 0.6025191071
# bestIteration = 50
#
# Training on fold [0/3]
#
# bestTest = 0.6359068464
# bestIteration = 69
#
# Training on fold [1/3]
#
# bestTest = 0.6813868025
# bestIteration = 69
#
# Training on fold [2/3]
#
# bestTest = 0.5825319799
# bestIteration = 51
#
#
# bestTest = 0.6883412682
# bestIteration = 94
#
#
# bestTest = 0.6918700746
# bestIteration = 65
#
#
# bestTest = 0.6790690097
# bestIteration = 16
#
#
# bestTest = 0.6931109958
# bestIteration = 82
#
#
# bestTest = 0.7065860199
# bestIteration = 30
#
#
# bestTest = 0.6996193373
# bestIteration = 74
#
#
# bestTest = 0.6910812556
# bestIteration = 55
#
#
# bestTest = 0.6839622745
# bestIteration = 33
#
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6868549489
# bestIteration = 5
#
#
# bestTest = 0.6934733318
# bestIteration = 51
#
# Training on fold [0/3]
#
# bestTest = 0.6201765407
# bestIteration = 13
#
# Training on fold [1/3]
#
# bestTest = 0.6465629195
# bestIteration = 15
#
# Training on fold [2/3]
#
# bestTest = 0.6402311478
# bestIteration = 14
#
#
# bestTest = 0.6766740728
# bestIteration = 81
#
#
# bestTest = 0.6763955054
# bestIteration = 87
#
#
# bestTest = 0.6917302461
# bestIteration = 24
#
#
# bestTest = 0.6732178749
# bestIteration = 99
#
#
# bestTest = 0.6774002746
# bestIteration = 46
#
#
# bestTest = 0.6773757918
# bestIteration = 62
#
#
# bestTest = 0.6753522107
# bestIteration = 88
#
#
# bestTest = 0.6739521127
# bestIteration = 42
#
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.6911315071
# bestIteration = 5
#
#
# bestTest = 0.676313517
# bestIteration = 45
#
# Training on fold [0/3]
#
# bestTest = 0.7478219513
# bestIteration = 99
#
# Training on fold [1/3]
#
# bestTest = 0.7268085788
# bestIteration = 81
#
# Training on fold [2/3]
#
# bestTest = 0.6242672849
# bestIteration = 97
#
#
# bestTest = 0.7630617164
# bestIteration = 99
#
#
# bestTest = 0.7614543701
# bestIteration = 90
#
#
# bestTest = 0.7850296239
# bestIteration = 34
#
#
# bestTest = 0.7658706739
# bestIteration = 90
#
#
# bestTest = 0.7671949596
# bestIteration = 42
#
#
# bestTest = 0.759004665
# bestIteration = 73
#
#
# bestTest = 0.7724426041
# bestIteration = 81
#
#
# bestTest = 0.7608282355
# bestIteration = 53
#
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 0.7605896348
# bestIteration = 12
#
#
# bestTest = 0.7484310355
# bestIteration = 54
#
# Training on fold [0/3]
#
# bestTest = 0.6637923545
# bestIteration = 44
#
# Training on fold [1/3]
#
# bestTest = 0.7526794082
# bestIteration = 67
#
# Training on fold [2/3]
#
# bestTest = 0.7297537241
# bestIteration = 68

# %% [markdown]
# ### Save single output model

# %%
# time = current_time()
with open(f'../Model/catboost_single.pickle', 'wb' ) as f:
    pickle.dump(single_output_model_dic, f)

# %% [markdown]
# ```python
# model_dic[col_y]['model'].predict(train_x_after_fe)  # get predictions
# model_dic[col_y]['randomized_search_result']['params']  # get parameters
# model_dic[col_y]['randomized_search_result']['cv_results']['test-RMSE-mean']  # get metric result
# ```

# %% [markdown]
# * ### Save the list of target variable name

# %%
col_y_li = train_y_after_fe.columns.tolist()
with open(f'../Model/target_col_list.pickle', 'wb' ) as f:
    pickle.dump(col_y_li, f)

# %% [markdown]
# * ### Predict 6 target variable

# %%
array_li= [ single_output_model_dic[col_y]['model'].predict(train_x_after_fe).reshape(-1,1) for col_y in col_y_li ]
all_res = np.concatenate(array_li, axis=1)

# %%
temp = pd.DataFrame(all_res, columns=col_y_li)
# save model result
with open('../Data/meta/catboost_single_predict_train_y.pickle', 'wb') as f:
    pickle.dump(temp, f)

# %%
# Load y-scaler model
with open(f'../Model/standard_scaler_y.pickle', 'rb') as f:
    scaler_y = pickle.load(f)

# %%
predictions = scaler_y.inverse_transform(all_res)
targets = non_scaled_train_y
print(rmse_score(predictions, targets))
# Out:
# sensor_point5_i_value      7.177684
# sensor_point6_i_value      7.737494
# sensor_point7_i_value     13.083644
# sensor_point8_i_value     10.410481
# sensor_point9_i_value     12.000323
# sensor_point10_i_value     9.599019
# dtype: float64

# %% [markdown]
# ## 5. Muti-output Regressor
# Training one model for Muti-Output result.

# %%
params = {
    'loss_function': 'MultiRMSE',
    'random_seed': random_state,
    'early_stopping_rounds':100,
    'task_type': 'CPU',
    'verbose':False,
    'has_time':True,
}
model = CatBoostRegressor(**params)

grid = {
    'learning_rate': [0.05, 0.07, 0.09, 0.3],
    'iterations': [50, 60, 70, 80, 90, 100],
    'depth': [3, 4, 5, 6, 7],
    'l2_leaf_reg': [1, 3, 5, 7, 9],
    'grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide']
}

randomized_search_result = model.randomized_search(
    grid,
    X=train_x_after_fe,
    y=train_y_after_fe,
    cv=3,
    partition_random_seed=random_state,
    plot=False,
    verbose=False
)
model_muti_output_dic = {'model': model, 'randomized_search_result': randomized_search_result}
# Out:
# bestTest = 1.721603953
# bestIteration = 79
#
#
# bestTest = 1.66595969
# bestIteration = 35
#
#
# bestTest = 1.657399866
# bestIteration = 69
#
#
# bestTest = 1.649586526
# bestIteration = 59
#
#
# bestTest = 1.597904734
# bestIteration = 62
#
#
# bestTest = 1.613736376
# bestIteration = 72
#
#
# bestTest = 1.672710653
# bestIteration = 99
#
#
# bestTest = 1.62740129
# bestIteration = 54
#
#
# bestTest = 1.678627738
# bestIteration = 99
#
#
# bestTest = 1.643451628
# bestIteration = 79
#
# Training on fold [0/3]
#
# bestTest = 1.530720673
# bestIteration = 67
#
# Training on fold [1/3]
#
# bestTest = 1.639366844
# bestIteration = 68
#
# Training on fold [2/3]
#
# bestTest = 1.54810075
# bestIteration = 56

# %%
predictions = scaler_y.inverse_transform( model_muti_output_dic['model'].predict(train_x_after_fe) )
targets = non_scaled_train_y
print(rmse_score(predictions, targets))
# Out:
# sensor_point5_i_value      6.613232
# sensor_point6_i_value      9.813324
# sensor_point7_i_value     12.953555
# sensor_point8_i_value     11.020815
# sensor_point9_i_value     10.321013
# sensor_point10_i_value     9.293708
# dtype: float64

# %%
with open(f'../Model/catboost_all.pickle', 'wb' ) as f:
    pickle.dump(model_muti_output_dic['model'], f)

# %%
temp = pd.DataFrame(model_muti_output_dic['model'].predict(train_x_after_fe), columns=col_y_li)
# save model result
with open('../Data/meta/catboost_all_predict_train_y.pickle', 'wb') as f:
    pickle.dump(temp, f)
