# %% [markdown]
# # Model training
# ---
# Description:
#
# In this notebook, you can generate two solutions.
# One is using 6 `single output regressor` to predict 6 target variable respectively, and the other is `muti-output regressor` that can output 6 predictions of target variable. It depends on `model_train_config.py` to lead the data flow.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
# basic
import pandas as pd
import numpy as np
import pickle
import model_train_config
# utils
from utils.time_utils import current_time
from utils.metric_utils import rmse_score
# model
from catboost import CatBoostRegressor
from catboost import cv, Pool

import feature_engineering_config as fe_config  
from feature_engineering import Standardization

# %% [markdown]
# ## 2. Config

# %%
random_state = model_train_config.random_state

# %% [markdown]
# ## 3. Load Data

# %%
with open(f'../Data/meta/train_x_after_feature_engineering.pickle', 'rb') as f:
    train_x_after_fe = pickle.load(f)

# %%
with open(f'../Data/meta/train_y_after_feature_engineering.pickle', 'rb') as f:
    train_y_after_fe = pickle.load(f)

# %%
# You need to use original values of target variable to evaluate RMSE
with open(f'../Data/meta/non_scaled_train_y_after_feature_engineering.pickle', 'rb') as f:
    non_scaled_train_y = pickle.load(f)

# %%
train_y_after_fe.head()
# Out:
#    sensor_point5_i_value  sensor_point6_i_value  sensor_point7_i_value  \
# 0              -2.875155              -1.366112              -1.107743
# 1              -3.261590              -1.215837              -2.053786
# 4              -1.715849              -0.539601              -1.896112
# 5              -2.875155              -0.765013              -1.028906
# 6              -2.411432              -0.765013              -0.713558
#
#    sensor_point8_i_value  sensor_point9_i_value  sensor_point10_i_value
# 0              -1.662985              -0.752201               -2.795963
# 1              -1.706093              -1.202112               -2.974941
# 4              -1.231903              -1.202112               -1.602776
# 5              -1.102578              -1.602033               -1.662436
# 6              -1.662985              -0.602231               -2.616985

# %%
train_x_after_fe.head()
# Out:
#    clean_pressure31  clean_pressure33  clean_pressure41  clean_pressure51  \
# 0         -0.845269         -2.274242          2.327716          2.163639
# 1         -0.845888         -2.273734          2.327716          2.172853
# 4         -0.855656         -2.295590          2.327716          2.168243
# 5         -0.855656         -2.295590          2.327716          2.168243
# 6         -0.855656         -2.295590          2.327716          2.168243
#
#    clean_pressure52  clean_pressure61  clean_pressure71  clean_pressure72  \
# 0         -2.965910          1.903804          0.434963          2.902725
# 1         -2.965910          1.903804          0.427070          2.906072
# 4         -2.964846          1.903804          0.380329          2.902725
# 5         -2.964846          1.903804          0.380329          2.902725
# 6         -2.964846          1.903804          0.380329          2.902725
#
#    clean_pressure81  clean_pressure91  ...  clean_pressure82_group  \
# 0          1.936083         -0.427078  ...                       5
# 1          1.950879         -0.471062  ...                       5
# 4          1.807915         -0.562123  ...                       5
# 5          1.807915         -0.562123  ...                       5
# 6          1.807915         -0.562123  ...                       5
#
#    oven_pb1_group  oven_pb2_group  oven_a1_group  oven_b1_group  \
# 0               5               3              2              2
# 1               5               3              2              2
# 4               5               3              2              2
# 5               5               3              2              2
# 6               5               3              2              2
#
#    oven_b3_group  painting_g3_act_hvv_group  painting_g8_act_f_air_group  \
# 0              1                          3                            0
# 1              1                          3                            0
# 4              1                          3                            0
# 5              1                          3                            0
# 6              1                          3                            0
#
#    painting_g9_act_hvc_group  env_rpi05_temp_group
# 0                          4                     1
# 1                          4                     1
# 4                          1                     1
# 5                          1                     1
# 6                          1                     1
#
# [5 rows x 60 columns]

# %%
categorical_features_indices = np.where(train_x_after_fe.dtypes != float)[0]

# %% [markdown]
# ## 4. Single Output Regressor
#
# Training model for each target variable.

# %%
single_output_model_dic = {}
for col_y in train_y_after_fe.columns:

    params = {
        'loss_function': 'RMSE',
        'random_seed': random_state,
        'early_stopping_rounds':100,
        'task_type': 'CPU',
        'verbose':False,
        'has_time':True,
    }
    model = CatBoostRegressor(**params)

    grid = {
        'learning_rate': [0.05, 0.07, 0.09, 0.3],
        'iterations': [50, 60, 70, 80, 90, 100, 120, ],
        'depth': [3, 4, 5, 6, 7],
        'l2_leaf_reg': [1, 3, 5, 7, 9],
        'grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide']
    }
    randomized_search_result = model.randomized_search(
        grid,
        X=train_x_after_fe,
        y=train_y_after_fe[col_y],
        cv=3,
        plot=False,
        verbose=False
    )
    
    single_output_model_dic[col_y] = {'model': model, 'randomized_search_result': randomized_search_result}
# Out:
# bestTest = 0.6109975691
# bestIteration = 34
#
#
# bestTest = 0.6321284684
# bestIteration = 79
#
#
# bestTest = 0.6019160312
# bestIteration = 89
#
#
# bestTest = 0.6100136827
# bestIteration = 68
#
#
# bestTest = 0.5960791858
# bestIteration = 94
#
#
# bestTest = 0.6028758507
# bestIteration = 119
#
#
# bestTest = 0.6048874831
# bestIteration = 69
#
#
# bestTest = 0.6152167909
# bestIteration = 79
#
#
# bestTest = 0.6237244652
# bestIteration = 29
#
#
# bestTest = 0.5999834183
# bestIteration = 69
#
# Training on fold [0/3]
#
# bestTest = 0.572216132
# bestIteration = 98
#
# Training on fold [1/3]
#
# bestTest = 0.7431476648
# bestIteration = 90
#
# Training on fold [2/3]
#
# bestTest = 0.6467753362
# bestIteration = 89
#
#
# bestTest = 0.5012956617
# bestIteration = 59
#
#
# bestTest = 0.5182713867
# bestIteration = 79
#
#
# bestTest = 0.4996115642
# bestIteration = 89
#
#
# bestTest = 0.4663398266
# bestIteration = 89
#
#
# bestTest = 0.4595414079
# bestIteration = 99
#
#
# bestTest = 0.4915816021
# bestIteration = 119
#
#
# bestTest = 0.4882979502
# bestIteration = 69
#
#
# bestTest = 0.4919977242
# bestIteration = 79
#
#
# bestTest = 0.4729119624
# bestIteration = 98
#
#
# bestTest = 0.4869842551
# bestIteration = 69
#
# Training on fold [0/3]
#
# bestTest = 0.4834997608
# bestIteration = 95
#
# Training on fold [1/3]
#
# bestTest = 0.4214042962
# bestIteration = 92
#
# Training on fold [2/3]
#
# bestTest = 0.4951475215
# bestIteration = 75
#
#
# bestTest = 0.6574118757
# bestIteration = 37
#
#
# bestTest = 0.656933239
# bestIteration = 67
#
#
# bestTest = 0.6359229269
# bestIteration = 83
#
#
# bestTest = 0.6454817851
# bestIteration = 47
#
#
# bestTest = 0.6234516951
# bestIteration = 64
#
#
# bestTest = 0.6337487635
# bestIteration = 111
#
#
# bestTest = 0.6238193416
# bestIteration = 69
#
#
# bestTest = 0.6295804774
# bestIteration = 79
#
#
# bestTest = 0.6421812788
# bestIteration = 21
#
#
# bestTest = 0.6255071985
# bestIteration = 69
#
# Training on fold [0/3]
#
# bestTest = 0.6541267823
# bestIteration = 97
#
# Training on fold [1/3]
#
# bestTest = 0.602225456
# bestIteration = 77
#
# Training on fold [2/3]
#
# bestTest = 0.6129516703
# bestIteration = 60
#
#
# bestTest = 0.5403949866
# bestIteration = 53
#
#
# bestTest = 0.5550663251
# bestIteration = 78
#
#
# bestTest = 0.5454109551
# bestIteration = 89
#
#
# bestTest = 0.560870526
# bestIteration = 89
#
#
# bestTest = 0.5384040488
# bestIteration = 99
#
#
# bestTest = 0.5490514044
# bestIteration = 113
#
#
# bestTest = 0.5453562142
# bestIteration = 69
#
#
# bestTest = 0.5500501258
# bestIteration = 79
#
#
# bestTest = 0.5456558926
# bestIteration = 17
#
#
# bestTest = 0.5435243327
# bestIteration = 64
#
# Training on fold [0/3]
#
# bestTest = 0.6692142236
# bestIteration = 55
#
# Training on fold [1/3]
#
# bestTest = 0.6307152722
# bestIteration = 97
#
# Training on fold [2/3]
#
# bestTest = 0.5411611969
# bestIteration = 51
#
#
# bestTest = 0.7038801484
# bestIteration = 55
#
#
# bestTest = 0.7146581294
# bestIteration = 69
#
#
# bestTest = 0.7099318472
# bestIteration = 89
#
#
# bestTest = 0.6942419942
# bestIteration = 86
#
#
# bestTest = 0.6951732073
# bestIteration = 83
#
#
# bestTest = 0.7060451206
# bestIteration = 115
#
#
# bestTest = 0.6995455503
# bestIteration = 64
#
#
# bestTest = 0.7054285793
# bestIteration = 77
#
#
# bestTest = 0.7032127992
# bestIteration = 56
#
#
# bestTest = 0.7060295148
# bestIteration = 69
#
# Training on fold [0/3]
#
# bestTest = 0.6931226421
# bestIteration = 89
#
# Training on fold [1/3]
#
# bestTest = 0.7010290204
# bestIteration = 58
#
# Training on fold [2/3]
#
# bestTest = 0.6629592706
# bestIteration = 60
#
#
# bestTest = 0.7587823542
# bestIteration = 57
#
#
# bestTest = 0.7848374356
# bestIteration = 79
#
#
# bestTest = 0.7495384085
# bestIteration = 89
#
#
# bestTest = 0.7314893103
# bestIteration = 79
#
#
# bestTest = 0.7329341038
# bestIteration = 99
#
#
# bestTest = 0.7472866458
# bestIteration = 118
#
#
# bestTest = 0.7391371628
# bestIteration = 67
#
#
# bestTest = 0.7369827235
# bestIteration = 79
#
#
# bestTest = 0.7552083372
# bestIteration = 55
#
#
# bestTest = 0.7386619883
# bestIteration = 69
#
# Training on fold [0/3]
#
# bestTest = 0.594446404
# bestIteration = 47
#
# Training on fold [1/3]
#
# bestTest = 0.7189711753
# bestIteration = 45
#
# Training on fold [2/3]
#
# bestTest = 0.7966761389
# bestIteration = 70

# %% [markdown]
# ### Save single output model

# %%
time = current_time()
with open(f'../Model/catboost_single_{time}.pickle', 'wb' ) as f:
    pickle.dump(single_output_model_dic, f)

# %% [markdown]
# ```python
# model_dic[col_y]['model'].predict(train_x_after_fe)  # get predictions
# model_dic[col_y]['randomized_search_result']['params']  # get parameters
# model_dic[col_y]['randomized_search_result']['cv_results']['test-RMSE-mean']  # get metric result
# ```

# %% [markdown]
# * ### Save the list of target variable name

# %%
col_y_li = train_y_after_fe.columns.tolist()
with open(f'../Model/target_col_list.pickle', 'wb' ) as f:
    pickle.dump(col_y_li, f)

# %% [markdown]
# * ### Predict 6 target variable

# %%
array_li= [ single_output_model_dic[col_y]['model'].predict(train_x_after_fe).reshape(-1,1) for col_y in col_y_li ]
all_res = np.concatenate(array_li, axis=1)

# %%
# Load y-scaler model
with open(f'../Model/standard_scaler_y.pickle', 'rb') as f:
    scaler_y = pickle.load(f)

# %%
predictions = scaler_y.inverse_transform(all_res)
targets = non_scaled_train_y
print(rmse_score(predictions, targets))
# Out:
# sensor_point5_i_value      6.663888
# sensor_point6_i_value      9.495002
# sensor_point7_i_value     12.598776
# sensor_point8_i_value     10.701720
# sensor_point9_i_value     10.518761
# sensor_point10_i_value     9.158507
# dtype: float64

# %% [markdown]
# ## 5. Muti-output Regressor
# Training one model for Muti-Output result.

# %%
params = {
    'loss_function': 'MultiRMSE',
    'random_seed': random_state,
    'early_stopping_rounds':100,
    'task_type': 'CPU',
    'verbose':False,
    'has_time':True,
}
model = CatBoostRegressor(**params)

grid = {
    'learning_rate': [0.05, 0.07, 0.09, 0.3],
    'iterations': [50, 60, 70, 80, 90, 100],
    'depth': [3, 4, 5, 6, 7],
    'l2_leaf_reg': [1, 3, 5, 7, 9],
    'grow_policy': ['SymmetricTree', 'Depthwise', 'Lossguide']
}

randomized_search_result = model.randomized_search(
    grid,
    X=train_x_after_fe,
    y=train_y_after_fe,
    cv=3,
    partition_random_seed=random_state,
    plot=False,
    verbose=False
)
model_muti_output_dic = {'model': model, 'randomized_search_result': randomized_search_result}
# Out:
# bestTest = 1.728735673
# bestIteration = 69
#
#
# bestTest = 1.697672077
# bestIteration = 79
#
#
# bestTest = 1.603510882
# bestIteration = 49
#
#
# bestTest = 1.625161475
# bestIteration = 49
#
#
# bestTest = 1.89781322
# bestIteration = 49
#
#
# bestTest = 1.743687381
# bestIteration = 89
#
#
# bestTest = 1.596771665
# bestIteration = 69
#
#
# bestTest = 1.533173417
# bestIteration = 82
#
#
# bestTest = 1.557608104
# bestIteration = 79
#
#
# bestTest = 1.666167591
# bestIteration = 59
#
# Training on fold [0/3]
#
# bestTest = 1.520832039
# bestIteration = 74
#
# Training on fold [1/3]
#
# bestTest = 1.588909351
# bestIteration = 76
#
# Training on fold [2/3]
#
# bestTest = 1.576418112
# bestIteration = 82

# %%
predictions = scaler_y.inverse_transform( model_muti_output_dic['model'].predict(train_x_after_fe) )
targets = non_scaled_train_y
print(rmse_score(predictions, targets))
# Out:
# sensor_point5_i_value      6.525038
# sensor_point6_i_value      9.863718
# sensor_point7_i_value     12.481714
# sensor_point8_i_value     10.718974
# sensor_point9_i_value     10.216413
# sensor_point10_i_value     9.001918
# dtype: float64

# %%
with open(f'../Model/catboost_all_{time}.pickle', 'wb' ) as f:
    pickle.dump(model_muti_output_dic['model'], f)
